# %%
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %%
link = "https://covid19.ncdc.gov.ng/"
r = requests.get(link)
print(r.status_code)
site = r.text
site_tables = pd.read_html(site)
# Out:
# 200

# %%
df = pd.DataFrame(site_tables[0])

# %%
df
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0            Lagos                        102877                          129
# 1              FCT                         29075                          146
# 2           Rivers                         17680                          262
# 3           Kaduna                         11467                           11
# 4              Oyo                         10327                            6
# 5          Plateau                         10292                           18
# 6              Edo                          7821                          102
# 7             Ogun                          5810                           11
# 8            Delta                          5631                          349
# 9             Ondo                          5173                          315
# 10            Kano                          5169                           41
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   States Affected               37 non-null     object
#  1   No. of Cases (Lab Confirmed)  37 non-null     int64
#  2   No. of Cases (on admission)   37 non-null     int64
#  3   No. Discharged                37 non-null     int64
#  4   No. of Deaths                 37 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.6+ KB

# %%
df.columns
# Out:
# Index(['States Affected', 'No. of Cases (Lab Confirmed)',
#        'No. of Cases (on admission)', 'No. Discharged', 'No. of Deaths'],
#       dtype='object')

# %%
sns.catplot(y='States Affected', x='No. of Cases (Lab Confirmed)', data=df, kind='bar', aspect=2, height=7)

# %%
df.dtypes
# Out:
# States Affected                 object
# No. of Cases (Lab Confirmed)     int64
# No. of Cases (on admission)      int64
# No. Discharged                   int64
# No. of Deaths                    int64
# dtype: object

# %%
df.plot(kind='bar', stacked=True, figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
ab = df.groupby('States Affected')

# %%
abj_1 = ab.get_group("FCT")

# %%
abj_1
# Out:
#   States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 1             FCT                         29075                          146
#
#    No. Discharged  No. of Deaths
# 1           28680            249
